# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorly.decomposition import parafac2
import tensorly as tl
from scipy.stats.mstats import gmean
from tensorly.parafac2_tensor import parafac2_to_slice
from tensorly.metrics.regression import variance as tl_var
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from tfac.figures.figureCommon import subplotLabel, getSetup
from sklearn.metrics import roc_curve, roc_auc_score
from tfac.MRSA_dataHelpers import produce_outcome_bools, get_patient_info, form_MRSA_tensor, form_paired_tensor, importClinicalMRSA, clinicalCyto, importExpressionData, find_regularization, find_CV_proba
from tfac.tensor import R2Xparafac2, MRSA_decomposition
from sklearn.model_selection import cross_val_predict

tl.set_backend("numpy")

# %%
components = 38
df = pd.DataFrame(AllR2X)

comps = []
for i in range(1, components + 1):
    comps.append(i)
df['Component'] = comps

df.columns = ['Cytokines', 'GeneIDs', 'Methylation', 'Component']
test = pd.melt(df, id_vars=['Component'])
ax, f = getSetup((7, 7), (1, 1))
b = sns.scatterplot(data=test, x='Component', y='value', hue='variable', style='variable', ax=ax[0], s=100)
b.set_xlabel("Component", fontsize=20)
b.set_ylabel("R2X", fontsize=20)
b.tick_params(labelsize=15)
plt.legend(prop={'size': 15})
ax[0].set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
def find_CV_proba(patient_matrix, outcomes, random_state=None, C=1):
    proba = cross_val_predict(LogisticRegression(penalty='l1', solver='saga', C=C, random_state=random_state, max_iter=10000, fit_intercept=False), patient_matrix, outcomes, cv=30, method="predict_proba")
    return proba[:, 1]

# %%
_, statusID = get_patient_info()
outcomes = produce_outcome_bools(statusID)
components = 38
patient_matrices = pickle.load( open( "parafac2tensors_newcyto.p", "rb" ) )
patient_matrices2 = pickle.load( open( "parafac2tensors_newcyto_2.p", "rb" ) )
patient_matrices3 = pickle.load( open( "parafac2tensors_newcyto_3.p", "rb" ) )
all_mats = [patient_matrices, patient_matrices2, patient_matrices3]
values_comps = []
for components in range(1, components + 1):
    for patient_matrices in all_mats:
        patient_matrix = patient_matrices[components - 1][1][2]
        reg = find_regularization(patient_matrix, outcomes)
        proba = find_CV_proba(patient_matrix, outcomes, random_state=None, C=reg)        
        auc = roc_auc_score(outcomes, proba)
        values_comps.append([components, auc])
df_comp = pd.DataFrame(values_comps)
df_comp.columns = ['Components', 'AUC']

# %%
ax, f = getSetup((15, 8), (1, 1))
b = sns.pointplot(data=df_comp, x='Components', y='AUC', ax=ax[0], s=70, join=False) # blue
b.set_xlabel("Components",fontsize=20)
b.set_ylabel("AUC",fontsize=20)
b.tick_params(labelsize=14)
ax[0].set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# # SVC attempt

# %%
from sklearn.svm import SVC

# %%
def find_SVC_proba(patient_matrix, outcomes):
    proba = cross_val_predict(SVC(probability=True), patient_matrix, outcomes, cv=30, method="predict_proba")
    return proba[:, 1]

# %%
_, statusID = get_patient_info()
outcomes = produce_outcome_bools(statusID)
components = 38
patient_matrices = pickle.load( open( "parafac2tensors_newcyto.p", "rb" ) )
values_comps = []
patient_matrix = patient_matrices[components - 1][1][2]
for i in range(0, components - 1):
    for j in range(i + 1, components):
        double = np.vstack((patient_matrix[:, i], patient_matrix[:, j])).T
        decisions = find_SVC_proba(double, outcomes)        
        auc = roc_auc_score(outcomes, decisions)
        values_comps.append([i, j, auc])
df_comp = pd.DataFrame(values_comps)
df_comp.columns = ["First", "Second", "AUC"]

# %%
pd.set_option("display.min_rows", 20)
df_comp = df_comp.sort_values(by=["AUC"], ascending=False)
display(df_comp)
# Out:
#      First  Second       AUC
# 92       2      22  0.785556
# 571     21      26  0.768889
# 277      8      18  0.756111
# 449     14      37  0.751111
# 91       2      21  0.751111
# 167      4      30  0.750000
# 430     14      18  0.743333
# 126      3      22  0.741111
# 637     26      27  0.741111
# 79       2       9  0.738889
# ..     ...     ...       ...
# 281      8      22  0.235556
# 621     24      34  0.233333
# 323      9      36  0.232222
# 554     20      25  0.226667
# 695     33      36  0.225556
# 607     23      33  0.220556
# 264      7      34  0.218333
# 293      8      34  0.217778
# 249      7      19  0.212222
# 620     24      33  0.210000
#
# [703 rows x 3 columns]

# %%
df_comp[df_comp["First"] == 2]
# Out:
#      First  Second       AUC
# 92       2      22  0.785556
# 91       2      21  0.751111
# 79       2       9  0.738889
# 73       2       3  0.708889
# 80       2      10  0.706111
# 82       2      12  0.702222
# 90       2      20  0.672222
# 86       2      16  0.654444
# 102      2      32  0.646667
# 84       2      14  0.598889
# ..     ...     ...       ...
# 101      2      31  0.403889
# 97       2      27  0.401111
# 107      2      37  0.392222
# 98       2      28  0.381111
# 99       2      29  0.336667
# 77       2       7  0.323889
# 106      2      36  0.298889
# 88       2      18  0.280000
# 78       2       8  0.245000
# 95       2      25  0.242222
#
# [35 rows x 3 columns]

# %%
_, statusID = get_patient_info()
outcomes = produce_outcome_bools(statusID)
components = 38
patient_matrices = pickle.load( open( "parafac2tensors_newcyto.p", "rb" ) )
values_comps = []
patient_matrix = patient_matrices[components - 1][1][2]
for i in range(0, components - 2):
    for j in range(i + 1, components - 1):
        for k in range(j + 1, components):
            triple = np.vstack((patient_matrix[:, i], patient_matrix[:, j], patient_matrix[:, k])).T
            decisions = find_SVC_proba(triple, outcomes)        
            auc = roc_auc_score(outcomes, decisions)
            values_comps.append([i, j, k, auc])
df_comp = pd.DataFrame(values_comps)
df_comp.columns = ["First", "Second", "Third", "AUC"]
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     807             try:
# --> 808                 tasks = self._ready_batches.get(block=False)
#     809             except queue.Empty:
#
# /usr/lib/python3.8/queue.py in get(self, block, timeout)
#     166                 if not self._qsize():
# --> 167                     raise Empty
#     168             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-151-384d58a8a61d> in <module>
#       9         for k in range(j + 1, components):
#      10             triple = np.vstack((patient_matrix[:, i], patient_matrix[:, j], patient_matrix[:, k])).T
# ---> 11             decisions = find_SVC_proba(triple, outcomes)
#      12             auc = roc_auc_score(outcomes, decisions)
#      13             values_comps.append([i, j, k, auc])
#
# <ipython-input-148-e47d6f36b002> in find_SVC_proba(patient_matrix, outcomes)
#       1 def find_SVC_proba(patient_matrix, outcomes):
# ----> 2     proba = cross_val_predict(SVC(probability=True), patient_matrix, outcomes, cv=30, method="predict_proba")
#       3     return proba[:, 1]
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#     769     parallel = Parallel(n_jobs=n_jobs, verbose=verbose,
#     770                         pre_dispatch=pre_dispatch)
# --> 771     prediction_blocks = parallel(delayed(_fit_and_predict)(
#     772         clone(estimator), X, y, train, test, verbose, fit_params, method)
#     773         for train, test in cv.split(X, y, groups))
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# /usr/local/lib/python3.8/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     817                 big_batch_size = batch_size * n_jobs
#     818
# --> 819                 islice = list(itertools.islice(iterator, big_batch_size))
#     820                 if len(islice) == 0:
#     821                     return False
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py in <genexpr>(.0)
#     770                         pre_dispatch=pre_dispatch)
#     771     prediction_blocks = parallel(delayed(_fit_and_predict)(
# --> 772         clone(estimator), X, y, train, test, verbose, fit_params, method)
#     773         for train, test in cv.split(X, y, groups))
#     774
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py in clone(estimator, safe)
#      85     new_object_params = estimator.get_params(deep=False)
#      86     for name, param in new_object_params.items():
# ---> 87         new_object_params[name] = clone(param, safe=False)
#      88     new_object = klass(**new_object_params)
#      89     params_set = new_object.get_params(deep=False)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py in clone(estimator, safe)
#      69     elif not hasattr(estimator, 'get_params') or isinstance(estimator, type):
#      70         if not safe:
# ---> 71             return copy.deepcopy(estimator)
#      72         else:
#      73             if isinstance(estimator, type):
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     132     """
#     133
# --> 134     if memo is None:
#     135         memo = {}
#     136
#
# KeyboardInterrupt:

# %%
pd.set_option("display.min_rows", 20)
df_comp = df_comp.sort_values(by=["AUC"], ascending=False)
display(df_comp)

# %% [markdown]
# # Paired

# %%
from statsmodels.discrete.conditional_models import ConditionalLogit as clogit
clog = clogit(outcomes, patient_matrix, groups=pairs)
x = clog.fit_regularized(alpha=.0001, maxiter=1000, L1_wt=1)
y = clog.loglike(x.params)
model_ll = y
print(y)
# Out:
# -0.0905643114757213

# %%
import random
import copy
zeros = [1, 2, 3, 5, 6, 8, 9, 10, 11, 12, 13, 15, 16, 17, 18, 20, 21, 22, 23, 26, 27, 28, 30, 32, 33, 34]
indices = [0, 3, 4, 13, 17, 20, 23, 26, 28, 29, 30, 31, 32, 33, 34, 36, 38, 39, 40, 42, 43, 46, 50, 51, 55, 59]
pair = pd.DataFrame(pairs)
likelihoods = []
for _ in range(50):
    zero_copy = copy.deepcopy(zeros)
    new_pair = pair.copy()
    for index in indices:
        p = random.choice(zero_copy)
        new_pair.loc[index] = p
        zero_copy.remove(p)
    clog = clogit(outcomes, patient_matrix, groups=new_pair["pair"])
    x = clog.fit_regularized(alpha=.0001, maxiter=1000, L1_wt=1)
    y = clog.loglike(x.params)
    likelihoods.append(y)
print(np.median(likelihoods))
# Out:
# -0.08834460876661332

# %%
to_plot = pd.DataFrame(likelihoods)
ax, f = getSetup((12, 8), (1, 1))
b = sns.distplot(to_plot, hist=True, kde=False, color='r', ax=ax[0])
b.set_xlabel("Log Likelihood",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=14)
print(np.median(likelihoods))
#ax[0].set_ylim(0, 1)
plt.axvline(model_ll, 0,30)
# Out:
# -6.285019378955852

# %%
to_plot = pd.DataFrame(likelihoods)
ax, f = getSetup((12, 8), (1, 1))
b = sns.distplot(to_plot, bins=100, hist=True, kde=False, color='r', ax=ax[0])
b.set_xlabel("Log Likelihood",fontsize=20)
b.set_ylabel("Count",fontsize=20)
b.tick_params(labelsize=14)
#ax[0].set_ylim(0, 1)
plt.axvline(model_ll, 0, 30)

# %%
paired_tensor = pickle.load( open( "paired_parafac2_2.p", "rb" ) )
patient_matrix = paired_tensor[components - 1][1][2]

# %%
clog = clogit(outcomes, patient_matrix, groups=pairs)
x = clog.fit_regularized(alpha=.0001, maxiter=100, L1_wt=1)
y = clog.loglike(x.params)
print(y)
# Out:
# -0.11426467648119981

# %%
import random
import copy
zeros = [1, 2, 3, 5, 6, 8, 9, 10, 11, 12, 13, 15, 16, 17, 18, 20, 21, 22, 23, 26, 27, 28, 30, 32, 33, 34]
indices = [0, 3, 4, 13, 17, 20, 23, 26, 28, 29, 30, 31, 32, 33, 34, 36, 38, 39, 40, 42, 43, 46, 50, 51, 55, 59]
pair = pd.DataFrame(pairs)
for _ in range(20):
    zero_copy = copy.deepcopy(zeros)
    new_pair = pair.copy()
    for index in indices:
        p = random.choice(zero_copy)
        new_pair.loc[index] = p
        zero_copy.remove(p)
    clog = clogit(outcomes, patient_matrix, groups=new_pair["pair"])
    x = clog.fit_regularized(alpha=.0001, maxiter=100, L1_wt=1)
    y = clog.loglike(x.params)
    print(y)
# Out:
# -0.34261047852181803
# -0.12451227888145588
# -0.1434777958279314
# -0.08617327112745204
# -0.08075548334627503
# -0.05032944351197338
# -0.06278923996830939
# -0.06419226168865372
# -2.610358022190442
# -0.07039464458966149
# -0.09735534188464612
# -0.15914521817745741
# -0.5237703414684678
# -0.07439621404389563
# -0.12321835128972071
# -0.13598167321650534
# -0.07660086426640218
# -0.0973007365577967
# -0.15423229161627258
# -0.10964176719902285

# %%
paired_tensor = pickle.load( open( "paired_parafac2_3.p", "rb" ) )
patient_matrix = paired_tensor[components - 1][1][2]

# %%
clog = clogit(outcomes, patient_matrix, groups=pairs)
x = clog.fit_regularized(alpha=.0001, maxiter=100, L1_wt=1)
y = clog.loglike(x.params)
print(y)
# Out:
# -0.17886630828104888

# %%
import random
import copy
zeros = [1, 2, 3, 5, 6, 8, 9, 10, 11, 12, 13, 15, 16, 17, 18, 20, 21, 22, 23, 26, 27, 28, 30, 32, 33, 34]
indices = [0, 3, 4, 13, 17, 20, 23, 26, 28, 29, 30, 31, 32, 33, 34, 36, 38, 39, 40, 42, 43, 46, 50, 51, 55, 59]
pair = pd.DataFrame(pairs)
for _ in range(5):
    zero_copy = copy.deepcopy(zeros)
    new_pair = pair.copy()
    for index in indices:
        p = random.choice(zero_copy)
        new_pair.loc[index] = p
        zero_copy.remove(p)
    clog = clogit(outcomes, patient_matrix, groups=new_pair["pair"])
    x = clog.fit_regularized(alpha=.0001, maxiter=100, L1_wt=1)
    y = clog.loglike(x.params)
    print(y)
# Out:
# -0.04002999713686639
# -0.03734937852702559
# -0.04267349013060723
# -0.0397792606364436
# -0.054212530883261945

# %% [markdown]
# # LogisticRegressionCV

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorly.decomposition import parafac2
import tensorly as tl
from scipy.stats.mstats import gmean
from tensorly.parafac2_tensor import parafac2_to_slice
from tensorly.metrics.regression import variance as tl_var
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from tfac.figures.figureCommon import subplotLabel, getSetup
from sklearn.metrics import roc_curve, roc_auc_score
from tfac.MRSA_dataHelpers import produce_outcome_bools, get_patient_info, form_MRSA_tensor, form_paired_tensor, importClinicalMRSA, clinicalCyto, importExpressionData, import_methylation
from tfac.tensor import R2Xparafac2, MRSA_decomposition

tl.set_backend("numpy")

# %%
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import cross_val_predict

# %%
def find_regularization(patient_matrix, outcomes, random_state=None):
    clf = LogisticRegressionCV(Cs=10, cv=10, random_state=random_state, fit_intercept=False, penalty='l1', solver='saga', max_iter=100000).fit(patient_matrix, outcomes)
    reg = clf.C_
    return reg[0]

# %%
def find_CV_proba(patient_matrix, outcomes, random_state=None, C=1):
    proba = cross_val_predict(LogisticRegression(penalty='l1', solver='saga', C=C, random_state=random_state, max_iter=10000, fit_intercept=False), patient_matrix, outcomes, cv=30, method="predict_proba")
    return proba[:, 1]

# %%
def find_coefs(patient_matrix, outcomes, random_state=None, C=1):
    clf = LogisticRegression(penalty='l1', solver='saga', C=C, random_state=random_state, max_iter=10000, fit_intercept=False).fit(patient_matrix, outcomes)
    coef = clf.coef_
    return coef

# %%
_, statusID = get_patient_info()
outcomes = produce_outcome_bools(statusID)
components = 38
patient_matrices = []
tensor_slices, cytos, _, _ = form_MRSA_tensor(1, 1, 1)

# %%
_, statusID = get_patient_info()
outcomes = produce_outcome_bools(statusID)
components = 38
patient_matrices = pickle.load( open( "cv_patient_mats_meth.p", "rb" ) )
patient_matrices2 = pickle.load( open( "cv_patient_mats_meth2.p", "rb" ) )
patient_matrices3 = pickle.load( open( "cv_patient_mats_meth3.p", "rb" ) )
all_mats = [patient_matrices, patient_matrices2, patient_matrices3]
values_comps = []
for components in range(1, components + 1):
    for patient_matrices in all_mats:
        patient_matrix = patient_matrices[components - 1][1][2]
        reg = find_regularization(patient_matrix, outcomes)
        proba = find_CV_proba(patient_matrix, outcomes, random_state=None, C=reg)
        auc = roc_auc_score(outcomes, proba)
        values_comps.append([components, auc])
df_comp = pd.DataFrame(values_comps)
df_comp.columns = ['Components', 'AUC']

# %%
_, statusID = get_patient_info()
outcomes = produce_outcome_bools(statusID)
components = 20
patient_matrices = pickle.load( open( "cv_patient_mats_meth.p", "rb" ) )
patient_matrices2 = pickle.load( open( "cv_patient_mats_meth2.p", "rb" ) )
patient_matrices3 = pickle.load( open( "cv_patient_mats_meth3.p", "rb" ) )
all_mats = [patient_matrices, patient_matrices2, patient_matrices3]
patient_matrix = patient_matrices[components - 1][1][2]
clf = LogisticRegressionCV(Cs=10, cv=5, random_state=None, fit_intercept=False, penalty='l1', solver='saga', max_iter=100000).fit(patient_matrix, outcomes)
z = clf.coefs_paths_

# %%
cyto4 = patient_matrices[components-1][2][0].T[3]
cyto6 = patient_matrices[components-1][2][0].T[5]
cyto_df = pd.DataFrame([cyto4, cyto6, cytos]).T
cyto_df.index = cytos
cyto_df.columns = ["Component 4", "Component 6", "Cytokines"]
ax, f = getSetup((15, 8), (1, 1))
b = sns.scatterplot(data=cyto_df, x='Component 4', y='Component 6', ax=ax[0]) # blue
b.set_xlabel("Component 4",fontsize=20)
b.set_ylabel("Component 6",fontsize=20)
b.tick_params(labelsize=14)
def label_point(cyto_df, ax):
    for i, point in cyto_df.iterrows():
        ax.text(point['Component 4']+.002, point['Component 6'], str(point['Cytokines']), fontsize=15)

label_point(cyto_df, ax[0])

# %%
all_coefs = []
for i in range(5):
    comps_fordf = []
    for j in range(1, components + 1):
        comps_fordf.append(j)
    coef_df = pd.DataFrame(z[1][i][7])
    coef_df.columns = ["Coefficient Value"]
    coef_df["Component"] = comps_fordf
    all_coefs.append(coef_df)
all_coefs = pd.concat(all_coefs)

# %%
ax, f = getSetup((15, 8), (1, 1))
b = sns.boxplot(data=all_coefs, x='Component', y='Coefficient Value', ax=ax[0]) # blue
b.set_xlabel("Components",fontsize=20)
b.set_ylabel("Coefficient Value",fontsize=20)
b.tick_params(labelsize=14)

# %%
x = np.mean(tensor_slices[0], axis=1)
dic = {}
for i in range(38):
    dic[cytos[i]] = np.round(x[i], 5)
[print(key, value) for (key, value) in sorted(dic.items(), key=lambda x: x[1])] 
print()
# Out:
# il1b 8e-05
# il2 0.00191
# il3 0.00225
# il5 0.00248
# il9 0.00248
# il12p70 0.00259
# il7 0.00272
# il15 0.00274
# il17a 0.00348
# il4 0.00368
# ifng 0.00404
# tgfa 0.00458
# gmcsf 0.00492
# flt3l 0.00582
# il12p40 0.00954
# ifna2 0.01117
# il1a 0.01454
# il13 0.01609
# fgf2 0.01612
# tnfa 0.01816
# fractalkine 0.0206
# il8 0.0208
# tnfb 0.02112
# mip1b 0.02191
# il6 0.02392
# gcsf 0.02605
# il10 0.03212
# mcp3 0.06169
# il1ra 0.06412
# egf 0.08467
# eotaxin 0.09215
# vegf 0.22119
# mdc 0.41589
# mcp1 0.51021
# mip1a 0.52258
# ip10 0.61124
# gro 2.18201
# scd40l 3.26869

# %%
from tensorly.parafac2_tensor import apply_parafac2_projections
components = 38
patient_matrices = pickle.load( open( "cv_patient_mats_meth.p", "rb" ) )
patient_matrices2 = pickle.load( open( "cv_patient_mats_meth2.p", "rb" ) )
patient_matrices3 = pickle.load( open( "cv_patient_mats_meth3.p", "rb" ) )
all_mats = [patient_matrices, patient_matrices2, patient_matrices3]
for patient_matrices in all_mats:
    patient_matrix = patient_matrices[components - 1][1][2]
    factors = apply_parafac2_projections(patient_matrices[components-1])
    cytokines = factors[1][1][0]
    reg = find_regularization(patient_matrix, outcomes)
    coefs = find_coefs(patient_matrix, outcomes, random_state=None, C=reg)
    combined1 = np.inner(cytokines, coefs)
    av = np.mean(tensor_slices[0], axis=1)
    av = np.reshape(av, (38, 1))
    combined2 = combined1 / av
    dic = {}
    for i in range(38):
        dic[cytos[i]] = np.round(combined2[i], 1)
    [print(key, value) for (key, value) in sorted(dic.items(), key=lambda x: x[1])] 
    print()
# Out:
# (38, 1)
# (38, 1)
# (38, 1)
# il9 [-5089.4]
# il15 [-5037.]
# il2 [-5031.7]
# il3 [-2475.9]
# il12p70 [-1948.3]
# il8 [-1179.8]
# mip1b [-732.4]
# il17a [-605.7]
# il13 [-354.9]
# il1a [-285.6]
# il12p40 [-243.]
# gcsf [-198.]
# il10 [-196.2]
# tgfa [-188.9]
# eotaxin [-94.2]
# egf [-37.8]
# gro [0.5]
# mip1a [3.6]
# mcp3 [5.7]
# scd40l [6.2]
# ip10 [9.8]
# mcp1 [11.2]
# vegf [13.2]
# il1ra [19.3]
# mdc [52.4]
# il6 [201.6]
# fgf2 [282.8]
# tnfb [464.8]
# tnfa [642.6]
# ifna2 [649.4]
# fractalkine [1036.8]
# flt3l [1392.7]
# ifng [1612.4]
# il4 [1683.3]
# il7 [2327.6]
# il5 [3012.6]
# gmcsf [3057.3]
# il1b [53067.5]
#
# (38, 1)
# (38, 1)
# (38, 1)
# ifng [-1607.]
# flt3l [-1386.3]
# il3 [-1003.9]
# tnfa [-578.7]
# mip1b [-106.4]
# fractalkine [-75.1]
# il13 [-70.8]
# il10 [-70.1]
# il1ra [-39.2]
# eotaxin [-36.5]
# ip10 [-20.2]
# mip1a [-19.9]
# fgf2 [-13.6]
# mdc [-7.8]
# vegf [1.4]
# mcp1 [2.8]
# scd40l [3.3]
# gro [9.3]
# egf [12.2]
# gcsf [15.]
# ifna2 [27.1]
# il9 [67.7]
# mcp3 [68.6]
# il6 [227.6]
# il8 [245.]
# il1a [276.9]
# tgfa [433.6]
# il12p40 [496.6]
# il4 [729.]
# tnfb [745.9]
# il7 [756.8]
# il5 [831.8]
# gmcsf [1151.1]
# il17a [1900.6]
# il15 [2266.7]
# il2 [2590.9]
# il12p70 [3723.8]
# il1b [49728.8]
#
# (38, 1)
# (38, 1)
# (38, 1)
# il2 [-2719.]
# il7 [-2095.9]
# il15 [-1938.9]
# il9 [-1153.5]
# il13 [-1038.3]
# gmcsf [-909.7]
# il5 [-696.]
# fractalkine [-687.5]
# tgfa [-535.7]
# tnfb [-397.3]
# il17a [-254.4]
# il12p40 [-226.4]
# il12p70 [-178.2]
# egf [-107.6]
# flt3l [-103.8]
# il1ra [-75.6]
# ifna2 [-57.6]
# eotaxin [-50.1]
# il10 [-40.3]
# vegf [-14.4]
# scd40l [2.]
# ip10 [8.7]
# gro [13.]
# mdc [16.2]
# mip1a [17.4]
# mcp1 [24.6]
# mcp3 [31.8]
# il4 [87.4]
# tnfa [103.8]
# il8 [188.2]
# il6 [246.5]
# mip1b [278.]
# gcsf [295.5]
# il1a [461.7]
# fgf2 [481.8]
# il3 [522.4]
# ifng [1341.]
# il1b [40420.2]

# %% [raw]
# from tensorly.parafac2_tensor import apply_parafac2_projections, Parafac2Tensor, parafac2_to_slice
# components = 31
# patient_matrices = pickle.load( open( "cv_patient_mats_meth.p", "rb" ) )
# patient_matrices2 = pickle.load( open( "cv_patient_mats_meth2.p", "rb" ) )
# patient_matrices3 = pickle.load( open( "cv_patient_mats_meth3.p", "rb" ) )
# all_mats = [patient_matrices, patient_matrices2, patient_matrices3]
# for patient_matrices in all_mats:
#     patient_matrix = patient_matrices[components - 1][1][2]
#     reg = find_regularization(patient_matrix, outcomes)
#     coefs = find_coefs(patient_matrix, outcomes, random_state=None, C=reg)
#     cyto_slices = []
#     for comp in range(components):
#         weights = np.array([patient_matrices[components][0][comp]])
#         weights = np.reshape(weights, (weights.shape[0], 1))
#         A = patient_matrices[components][1][0][:, comp]
#         B = np.array([patient_matrices[components][1][1][comp, comp]])
#         C = patient_matrices[components][1][2][:, comp]
#         factors = [np.reshape(A, (A.shape[0], 1)), np.reshape(B, (B.shape[0], 1)), np.reshape(C, (C.shape[0], 1))]
#         proj1 = patient_matrices[components][2][0][:, comp]
#         proj2 = patient_matrices[components][2][1][:, comp]
#         proj3 = patient_matrices[components][2][2][:, comp]
#         projs = [np.reshape(proj1, (proj1.shape[0], 1)), np.reshape(proj2, (proj2.shape[0], 1)), np.reshape(proj3, (proj3.shape[0], 1))]
#         new_decomp = Parafac2Tensor((weights, factors, projs))
#         cyto_slice = parafac2_to_slice(new_decomp, 0)
#         cyto_slices.append(cyto_slice)
#     for idx, sliced in enumerate(cyto_slices):
#         sliced = sliced * coefs[0][idx]
#     final_cyto = sum(cyto_slices)
#     display(pd.DataFrame(final_cyto))

# %%
ax, f = getSetup((15, 8), (1, 1))
b = sns.pointplot(data=df_comp, x='Components', y='AUC', ax=ax[0], s=70, join=False) # blue
b.set_xlabel("Components",fontsize=20)
b.set_ylabel("AUC",fontsize=20)
b.tick_params(labelsize=14)
ax[0].set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
df = pd.DataFrame(cv_AllR2X)

comps = []
for i in range(1, components + 1):
    comps.append(i)
df['Component'] = comps

df.columns = ['Cytokines', 'GeneIDs', 'Methylation', 'Component']
test = pd.melt(df, id_vars=['Component'])
ax, f = getSetup((7, 7), (1, 1))
b = sns.scatterplot(data=test, x='Component', y='value', hue='variable', style='variable', ax=ax[0], s=100)
b.set_xlabel("Component", fontsize=20)
b.set_ylabel("R2X", fontsize=20)
b.tick_params(labelsize=15)
plt.legend(prop={'size': 15})
ax[0].set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# #

# %%
_, statusID = get_patient_info()
outcomes = produce_outcome_bools(statusID)
components = 38
patient_matrices = []
tensor_slices, _, _, _ = form_MRSA_tensor(15, 1, .1)

# %%
from tensorly.parafac2_tensor import apply_parafac2_projections
components = 30
patient_matrices = pickle.load( open( "scale_cv_patient_mats_meth.p", "rb" ) )
patient_matrices2 = pickle.load( open( "scale_cv_patient_mats_meth2.p", "rb" ) )
patient_matrices3 = pickle.load( open( "scale_cv_patient_mats_meth3.p", "rb" ) )
all_mats = [patient_matrices, patient_matrices2, patient_matrices3]
for patient_matrices in all_mats:
    patient_matrix = patient_matrices[components - 1][1][2]
    factors = apply_parafac2_projections(patient_matrices[components-1])
    cytokines = factors[1][1][0]
    reg = find_regularization(patient_matrix, outcomes)
    coefs = find_coefs(patient_matrix, outcomes, random_state=None, C=reg)
    combined = np.inner(cytokines, coefs)
    for i in range(38):
        print(np.round(combined[i], 0), cytos[i])
    print()
# Out:
# [4.] egf
# [-0.] eotaxin
# [-1.] tgfa
# [-4.] gcsf
# [1.] fractalkine
# [4.] ifng
# [-21.] gro
# [4.] il10
# [-3.] il12p40
# [-4.] mdc
# [-6.] il13
# [-0.] il15
# [-15.] scd40l
# [2.] il17a
# [-2.] il1ra
# [-2.] il5
# [1.] il6
# [2.] il8
# [3.] ip10
# [3.] mcp1
# [-4.] mip1a
# [3.] mip1b
# [3.] tnfa
# [-4.] vegf
# [1.] fgf2
# [1.] flt3l
# [-2.] gmcsf
# [-4.] ifna2
# [-2.] mcp3
# [-1.] il12p70
# [-0.] il1a
# [0.] il9
# [-0.] il1b
# [0.] il2
# [0.] il3
# [0.] il4
# [-0.] il7
# [4.] tnfb
#
# [-3.] egf
# [1.] eotaxin
# [-1.] tgfa
# [-4.] gcsf
# [-1.] fractalkine
# [1.] ifng
# [12.] gro
# [-11.] il10
# [2.] il12p40
# [-10.] mdc
# [1.] il13
# [-0.] il15
# [-14.] scd40l
# [2.] il17a
# [-6.] il1ra
# [0.] il5
# [-2.] il6
# [1.] il8
# [1.] ip10
# [0.] mcp1
# [-4.] mip1a
# [-7.] mip1b
# [2.] tnfa
# [-3.] vegf
# [3.] fgf2
# [1.] flt3l
# [3.] gmcsf
# [6.] ifna2
# [-1.] mcp3
# [4.] il12p70
# [2.] il1a
# [0.] il9
# [-0.] il1b
# [0.] il2
# [0.] il3
# [2.] il4
# [4.] il7
# [-2.] tnfb
#
# [0.] egf
# [0.] eotaxin
# [-0.] tgfa
# [-1.] gcsf
# [-0.] fractalkine
# [0.] ifng
# [-2.] gro
# [0.] il10
# [-0.] il12p40
# [-0.] mdc
# [-0.] il13
# [0.] il15
# [-0.] scd40l
# [0.] il17a
# [-1.] il1ra
# [-0.] il5
# [0.] il6
# [0.] il8
# [1.] ip10
# [-0.] mcp1
# [-1.] mip1a
# [-1.] mip1b
# [0.] tnfa
# [-1.] vegf
# [0.] fgf2
# [0.] flt3l
# [-0.] gmcsf
# [0.] ifna2
# [0.] mcp3
# [0.] il12p70
# [1.] il1a
# [-0.] il9
# [0.] il1b
# [0.] il2
# [0.] il3
# [-0.] il4
# [-0.] il7
# [0.] tnfb

# %%
_, statusID = get_patient_info()
outcomes = produce_outcome_bools(statusID)
components = 38
patient_matrices = pickle.load( open( "scale_cv_patient_mats_meth.p", "rb" ) )
patient_matrices2 = pickle.load( open( "scale_cv_patient_mats_meth2.p", "rb" ) )
patient_matrices3 = pickle.load( open( "scale_cv_patient_mats_meth3.p", "rb" ) )
all_mats = [patient_matrices, patient_matrices2, patient_matrices3]
values_comps = []
for components in range(1, components + 1):
    for patient_matrices in all_mats:
        patient_matrix = patient_matrices[components - 1][1][2]
        reg = find_regularization(patient_matrix, outcomes)
        proba = find_CV_proba(patient_matrix, outcomes, random_state=None, C=reg)        
        auc = roc_auc_score(outcomes, proba)
        values_comps.append([components, auc])
df_comp = pd.DataFrame(values_comps)
df_comp.columns = ['Components', 'AUC']

# %%
ax, f = getSetup((15, 8), (1, 1))
b = sns.pointplot(data=df_comp, x='Components', y='AUC', ax=ax[0], s=70, join=False) # blue
b.set_xlabel("Components",fontsize=20)
b.set_ylabel("AUC",fontsize=20)
b.tick_params(labelsize=14)
ax[0].set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
_, statusID = get_patient_info()
outcomes = produce_outcome_bools(statusID)
components = 38
patient_matrices = pickle.load( open( "scale_cv_patient_mats_meth.p", "rb" ) )
patient_matrices2 = pickle.load( open( "scale_cv_patient_mats_meth2.p", "rb" ) )
patient_matrices3 = pickle.load( open( "scale_cv_patient_mats_meth3.p", "rb" ) )
all_mats = [patient_matrices, patient_matrices2, patient_matrices3]
values_comps = []
for components in range(1, components + 1):
    for patient_matrices in all_mats:
        patient_matrix = patient_matrices[components - 1][1][2]
        #reg = find_regularization(patient_matrix, outcomes)
        score_y = find_CV_decisions(patient_matrix, outcomes, random_state=None, C=5)        
        auc = roc_auc_score(outcomes, score_y)
        values_comps.append([components, auc])
df_comp = pd.DataFrame(values_comps)
df_comp.columns = ['Components', 'AUC']

# %%
ax, f = getSetup((15, 8), (1, 1))
b = sns.pointplot(data=df_comp, x='Components', y='AUC', ax=ax[0], s=70, join=False) # blue
b.set_xlabel("Components",fontsize=20)
b.set_ylabel("AUC",fontsize=20)
b.tick_params(labelsize=14)
ax[0].set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
df = pd.DataFrame(scale_cv_AllR2X3)

comps = []
for i in range(1, components + 1):
    comps.append(i)
df['Component'] = comps

df.columns = ['Cytokines', 'GeneIDs', 'Methylation', 'Component']
test = pd.melt(df, id_vars=['Component'])

# %%
ax, f = getSetup((7, 7), (1, 1))
b = sns.scatterplot(data=test, x='Component', y='value', hue='variable', style='variable', ax=ax[0], s=100)
b.set_xlabel("Component", fontsize=20)
b.set_ylabel("R2X", fontsize=20)
b.tick_params(labelsize=15)
plt.legend(prop={'size': 15})
ax[0].set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# ## Before Variance scaling and logit cv

# %%
def find_CV_decisions(patient_matrix, outcomes, random_state=None, C=1):
    n_splits = patient_matrix.shape[0]
    kf = KFold(n_splits=n_splits)
    decisions = []
    for train, test in kf.split(patient_matrix):
        clf = LogisticRegression(penalty='l1', solver='saga', C=C, random_state=random_state, max_iter=10000, fit_intercept=False).fit(patient_matrix[train], outcomes[train])
        decisions.append(clf.decision_function(patient_matrix[test]))
    score_y = decisions
    return score_y

# %%
_, statusID = get_patient_info()
outcomes = produce_outcome_bools(statusID)
patient_matrices = pickle.load( open( "patient_mats_meth.p", "rb" ) )
patient_matrices2 = pickle.load( open( "patient_mats_meth2.p", "rb" ) )
patient_matrices3 = pickle.load( open( "patient_mats_meth3.p", "rb" ) )
all_mats = [patient_matrices, patient_matrices2, patient_matrices3]
values_comps = []
for components in range(1, 39):
    for patient_matrices in all_mats:
        patient_matrix = patient_matrices[components - 1][1][2]
        score_y = find_CV_decisions(patient_matrix, outcomes, random_state=None, C=5)
        auc = roc_auc_score(outcomes, score_y)
        values_comps.append([components, auc])
df_comp = pd.DataFrame(values_comps)
df_comp.columns = ['Components', 'AUC']

# %%
ax, f = getSetup((15, 8), (1, 1))
b = sns.pointplot(data=df_comp, x='Components', y='AUC', ax=ax[0], s=70, join=False) # blue
b.set_xlabel("Components",fontsize=20)
b.set_ylabel("AUC",fontsize=20)
b.tick_params(labelsize=14)
ax[0].set_ylim(0, 1)
#5, new decomp
# Out:
# (0.0, 1.0)

# %%
ax, f = getSetup((15, 8), (1, 1))
b = sns.pointplot(data=df_comp, x='Components', y='AUC', ax=ax[0], s=70, join=False) # blue
b.set_xlabel("Components",fontsize=20)
b.set_ylabel("AUC",fontsize=20)
b.tick_params(labelsize=14)
ax[0].set_ylim(0, 1)
#none saga, new decomp
# Out:
# (0.0, 1.0)

# %%
ax, f = getSetup((15, 8), (1, 1))
b = sns.pointplot(data=df_comp, x='Components', y='AUC', ax=ax[0], s=70, join=False) # blue
b.set_xlabel("Components",fontsize=20)
b.set_ylabel("AUC",fontsize=20)
b.tick_params(labelsize=14)
ax[0].set_ylim(0, 1)
#none lbfgs, new decomp
# Out:
# (0.0, 1.0)

# %%
ax, f = getSetup((15, 8), (1, 1))
b = sns.pointplot(data=df_comp, x='Components', y='AUC', ax=ax[0], s=70, join=False) # blue
b.set_xlabel("Components",fontsize=20)
b.set_ylabel("AUC",fontsize=20)
b.tick_params(labelsize=14)
ax[0].set_ylim(0, 1)
#1, new decomp
# Out:
# (0.0, 1.0)

# %%
ax, f = getSetup((15, 8), (1, 1))
b = sns.pointplot(data=df_comp, x='Components', y='AUC', ax=ax[0], s=70, join=False) # blue
b.set_xlabel("Components",fontsize=20)
b.set_ylabel("AUC",fontsize=20)
b.tick_params(labelsize=14)
ax[0].set_ylim(0, 1)
#10, new decomp
# Out:
# (0.0, 1.0)

# %%
ax, f = getSetup((15, 8), (1, 1))
b = sns.pointplot(data=df_comp, x='Components', y='AUC', ax=ax[0], s=70, join=False) # blue
b.set_xlabel("Components",fontsize=20)
b.set_ylabel("AUC",fontsize=20)
b.tick_params(labelsize=14)
ax[0].set_ylim(0, 1)
#100000000000, new decomp
# Out:
# (0.0, 1.0)

# %%
ax, f = getSetup((15, 8), (1, 1))
b = sns.pointplot(data=df_comp, x='Components', y='AUC', ax=ax[0], s=70, join=False) # blue
b.set_xlabel("Components",fontsize=20)
b.set_ylabel("AUC",fontsize=20)
b.tick_params(labelsize=14)
ax[0].set_ylim(0, 1)
#1000000

# %%
ax, f = getSetup((15, 8), (1, 1))
b = sns.pointplot(data=df_comp, x='Components', y='AUC', ax=ax[0], s=70, join=False) # blue
b.set_xlabel("Components",fontsize=20)
b.set_ylabel("AUC",fontsize=20)
b.tick_params(labelsize=14)
ax[0].set_ylim(0, 1)
#10
# Out:
# (0.0, 1.0)

# %%
df = pd.DataFrame(AllR2X)

comps = []
for i in range(1, components + 1):
    comps.append(i)
df['Component'] = comps

df.columns = ['Cytokines', 'GeneIDs', 'Methylation', 'Component']
test = pd.melt(df, id_vars=['Component'])

# %%
ax, f = getSetup((7, 7), (1, 1))
b = sns.scatterplot(data=test, x='Component', y='value', hue='variable', style='variable', ax=ax[0], s=100)
b.set_xlabel("Component", fontsize=20)
b.set_ylabel("R2X", fontsize=20)
b.tick_params(labelsize=15)
plt.legend(prop={'size': 15})
ax[0].set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
_, statusID = get_patient_info()
outcomes = produce_outcome_bools(statusID)
components = 2
patient_matrices = []
tensor_slices, _, _, _ = form_MRSA_tensor()

# %%
AllR2X = []
for component in range(1, components + 1):
    parafac2tensor = MRSA_decomposition(tensor_slices, component, random_state=None)
    patient_matrices.append(parafac2tensor[1][2])
    R2X = np.round(R2Xparafac2(tensor_slices, parafac2tensor), 6)
    print(R2X)
    AllR2X.append(R2X)
# Out:
# /usr/local/lib/python3.8/dist-packages/numpy/lib/function_base.py:792: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, order=order, subok=subok, copy=True)
# [0.387895 0.780529 0.984338]
# [0.389546 0.871045 0.984587]

# %%
_, statusID = get_patient_info(paired=True)
outcomes = produce_outcome_bools(statusID)
components = 38
patient_matrices = []
tensor_slices, _, _, _, pairs = form_paired_tensor()

# %%
AllR2X = []
for component in range(1, components + 1):
    parafac2tensor = MRSA_decomposition(tensor_slices, component, random_state=None)
    patient_matrices.append(parafac2tensor[1][2])
    R2X = np.round(R2Xparafac2(tensor_slices, parafac2tensor), 6)
    print(R2X)
    AllR2X.append(R2X)
# Out:
# [0.377334 0.798578 0.984483]
# [0.37876  0.884539 0.984773]
# [0.393143 0.916687 0.985092]
# [0.389018 0.918378 0.985903]
# [0.402588 0.923257 0.986547]
# [0.38591  0.948502 0.986948]
# [0.404839 0.958832 0.987296]
# [0.418233 0.96321  0.987695]
# [0.42256  0.96783  0.988049]
# [0.423195 0.972539 0.988017]
# [0.452046 0.97317  0.988794]
# [0.439836 0.974533 0.989159]
# [0.454153 0.977649 0.98944 ]
# [0.435005 0.977362 0.989786]
# [0.458875 0.9798   0.990082]
# [0.455961 0.982949 0.99036 ]
# [0.458344 0.982959 0.990697]
# [0.53059  0.984756 0.99099 ]
# [0.532879 0.985733 0.991308]
# [0.559772 0.986814 0.991598]
# [0.541183 0.987482 0.991899]
# [0.574334 0.988144 0.992202]
# [0.577064 0.988358 0.99251 ]
# [0.607101 0.989313 0.992796]
# [0.58956  0.99015  0.993074]
# [0.60407  0.991351 0.993353]
# [0.710614 0.992187 0.993919]
# [0.629605 0.992433 0.994198]
# [0.705443 0.993081 0.994478]
# [0.731078 0.993554 0.994755]
# [0.716909 0.994212 0.995027]
# [0.753767 0.994572 0.995299]
# [0.781831 0.994728 0.995567]
# [0.805566 0.995225 0.995834]
# [0.755928 0.995582 0.996099]
# [0.791797 0.995906 0.99636 ]
# [0.809854 0.996252 0.996622]

# %%
_, statusID = get_patient_info(paired=True)
outcomes = produce_outcome_bools(statusID)
components = 20
patient_matrices = []
tensor_slices, _, _, _, pairs = form_paired_tensor()
parafac2tensor = MRSA_decomposition(tensor_slices, components, random_state=None)
patient_matrix = parafac2tensor[1][2]

# %%
clog = clogit(outcomes, patient_matrix, groups=pairs)
x = clog.fit(method='nm', maxiter=200000, full_output=True, disp=True, retall=True)
x.params
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/discrete/conditional_models.py:266: RuntimeWarning: overflow encountered in exp
#   exb = np.exp(np.dot(self._exog_grp[grp], params) + ofs)
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 13288
#          Function evaluations: 16650
# /usr/local/lib/python3.8/dist-packages/statsmodels/base/model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warn('Inverting hessian failed, no bse or cov_params '
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-0cce45cbe17c> in <module>
#       1 clog = clogit(outcomes, patient_matrix, groups=pairs)
# ----> 2 x = clog.fit(method='nm', maxiter=200000, full_output=True, disp=True, retall=True)
#       3 x.params
#
# /usr/local/lib/python3.8/dist-packages/statsmodels/discrete/conditional_models.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     123             skip_hessian=skip_hessian)
#     124
# --> 125         crslt = ConditionalResults(self, rslt.params, rslt.cov_params(), 1)
#     126         crslt.method = method
#     127         crslt.nobs = self.nobs
#
# /usr/local/lib/python3.8/dist-packages/statsmodels/base/model.py in cov_params(self, r_matrix, column, scale, cov_p, other)
#    1430         if (cov_p is None and self.normalized_cov_params is None and
#    1431                 not hasattr(self, 'cov_params_default')):
# -> 1432             raise ValueError('need covariance of parameters for computing '
#    1433                              '(unnormalized) covariances')
#    1434         if column is not None and (r_matrix is not None or other is not None):
#
# ValueError: need covariance of parameters for computing (unnormalized) covariances

# %%
from statsmodels.discrete.conditional_models import ConditionalLogit as clogit

# %%
clog = clogit(outcomes, patient_matrix, groups=pairs)

# %%
x = clog.fit(method='nm', maxiter=200000, full_output=True, disp=True, retall=True)
x.params
# Out:
# Optimization terminated successfully.
#          Current function value: 0.265571
#          Iterations: 2407
#          Function evaluations: 3397
# array([-1.27684065, -4.86078408, -9.45583434, -0.8626829 , -3.73088421,
#        -6.45150749, -0.81418289,  4.50702796,  4.05880332, -3.41360825])

# %%
clog = clogit(outcomes, patient_matrix, groups=pairs)
x = clog.fit_regularized(alpha=.00001, maxiter=1000, L1_wt=1)
x.params
# Out:
# array([ -7.34165205,  10.03524345,   0.        ,   0.        ,
#         -6.94282907,   0.        ,   4.59718905,  10.29988273,
#          0.        ,   0.        ,   0.        , -14.99417231,
#         50.2177288 , -33.42564251,   0.        ,  -8.42279594,
#         -2.9902021 ,   0.        ,   0.        ,   0.        ])
